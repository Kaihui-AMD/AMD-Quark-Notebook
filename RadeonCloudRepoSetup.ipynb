# %% [markdown]
# # 04. Radeon Cloud Repo Setup
#
# 本章说明如何在 Radeon Cloud 环境中拉取本教程仓库，并确认 notebook 与辅助脚本路径。

# %% [markdown]
# ## 1. 拉取教程仓库
#
# 在 Radeon Cloud 环境中，如果默认 SSL 校验导致 GitHub clone 失败，可使用以下命令拉取本教程仓库：

# %%
# !git -c http.sslVerify=false clone https://github.com/Kaihui-AMD/AMD-Quark-Notebook.git

# %% [markdown]
# ## 2. 进入仓库目录
#
# 拉取完成后进入仓库目录，后续 notebook 和课程辅助脚本均从该目录访问。

# %%
# %cd AMD-Quark-Notebook
# !ls

# %% [markdown]
# ## 3. 检查课程脚本
#
# `course_scripts/vllm_chat_smoke.py` 用于验证 Quark 导出的模型能否被 vLLM 以 `--quantization quark` 方式加载并完成一次短文本生成。

# %%
# !ls course_scripts
# !python course_scripts/vllm_chat_smoke.py --help

# %% [markdown]
# ## 4. 后续步骤
#
# 完成仓库拉取后，可以打开：
#
# - `notebooks/03_SmoothQuantMXFP4.ipynb`
#
# 按照其中的命令完成 `Qwen2.5-7B-Instruct` 的 `mxfp4 + SmoothQuant` 量化导出与 vLLM smoke test。
